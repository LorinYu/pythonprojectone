# %%
import mysql.connector
conn = mysql.connector.connect(user='root', password='root', database='mathmodel')
cursor = conn.cursor()
#while(true):
    #cursor.execute('insert into user (id, name) values (%s, %s)', ['1', 'Michael'])
cursor.execute('select count(name) from table1 where jingdu-22.56614225 <=0.01 and weidu-113.9808368 <=0.01')
values = cursor.fetchall()
print(values)
cursor.close()
conn.close()
# Out:
# [(37,)]

# %%
import mysql.connector
conn = mysql.connector.connect(user='root', password='root', database='mathmodel')
cursor = conn.cursor()
#i=1
#while(i <= 835):
    #cursor.execute('insert into user (id, name) values (%s, %s)', ['1', 'Michael'])
cursor.execute('select jingdu from table1 where id = 1')
jingdu = cursor.fetchall()
cursor.execute('select weidu from table1 where id = 1')
weidu = cursor.fetchall()
    #cursor.execute('select count(name) from table1 where jingdu-22.56614225 <=0.01 and weidu-113.9808368 <=0.01')
    #values = cursor.fetchall()
print(jingdu,weidu)
    #i = i + 1
cursor.close()
conn.close()
# Out:
# [(Decimal('22.56614225'),)] [(Decimal('113.9808368'),)]

# %%
import mysql.connector
conn = mysql.connector.connect(user='root', password='root', database='mathmodel')
cursor = conn.cursor()
#i=1
#while(i <= 835):
    #cursor.execute('insert into user (id, name) values (%s, %s)', ['1', 'Michael'])
cursor.execute('select jingdu from table1 where id = 1')
jingdu = cursor.fetchall()
cursor.execute('select weidu from table1 where id = 1')
weidu = cursor.fetchall()
cursor.execute('select count(name) from table1 where jingdu- %s<=0.01 and weidu-%s <=0.01',[jingdu,weidu])
value = cursor.fetchall()
print(value)
    #i = i + 1
cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\mysql\connector\conversion.py in to_mysql(self, value)
#     159         try:
# --> 160             return getattr(self, "_{0}_to_mysql".format(type_name))(value)
#     161         except AttributeError:
#
# AttributeError: 'MySQLConverter' object has no attribute '_list_to_mysql'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\mysql\connector\cursor.py in _process_params(self, params)
#     373
# --> 374             res = [to_mysql(i) for i in res]
#     375             res = [escape(i) for i in res]
#
# D:\Anaconda3\lib\site-packages\mysql\connector\cursor.py in <listcomp>(.0)
#     373
# --> 374             res = [to_mysql(i) for i in res]
# ...

# %%
import mysql.connector
conn = mysql.connector.connect(user='root', password='root', database='mathmodel')
cursor = conn.cursor()
#while(true):
    #cursor.execute('insert into user (id, name) values (%s, %s)', ['1', 'Michael'])
cursor.execute('select count(name) from table1 where jingdu-22.56614225 <=0.01 and weidu-113.9808368 <=0.01')
values = cursor.fetchall()
print(values[0][0])
print(type(values[0][0]))
cursor.close()
conn.close()
# Out:
# 37
# <class 'int'>

# %%
import mysql.connector
conn = mysql.connector.connect(user='root', password='root', database='mathmodel')
cursor = conn.cursor()
#i=1
#while(i <= 835):
    #cursor.execute('insert into user (id, name) values (%s, %s)', ['1', 'Michael'])
cursor.execute('select jingdu from table1 where id = 1')
jingdu = cursor.fetchall()
cursor.execute('select weidu from table1 where id = 1')
weidu = cursor.fetchall()
    #cursor.execute('select count(name) from table1 where jingdu-22.56614225 <=0.01 and weidu-113.9808368 <=0.01')
    #values = cursor.fetchall()
print(jingdu[0][0],weidu[0][0])
    #i = i + 1
cursor.close()
conn.close()
# Out:
# 22.56614225 113.9808368

# %%
import mysql.connector
conn = mysql.connector.connect(user='root', password='root', database='mathmodel')
cursor = conn.cursor()
#i=1
#while(i <= 835):
    #cursor.execute('insert into user (id, name) values (%s, %s)', ['1', 'Michael'])
cursor.execute('select jingdu from table1 where id = 1')
jingdu = cursor.fetchall()
j1 = jingdu[0][0]
cursor.execute('select weidu from table1 where id = 1')
weidu= cursor.fetchall()
w1 = weidu[0][0]
cursor.execute('select count(name) from table1 where jingdu- %s<=0.01 and weidu-%s <=0.01',[j1,w1])
value = cursor.fetchall()
v1 = value[0][0]
print(v1)
    #i = i + 1
cursor.close()
conn.close()
# Out:
# 37

# %%
import mysql.connector
conn = mysql.connector.connect(user='root', password='root', database='mathmodel')
cursor = conn.cursor()
i=1
while(i <= 835):
    #cursor.execute('insert into user (id, name) values (%s, %s)', ['1', 'Michael'])
    cursor.execute('select jingdu from table1 where id = %s',[i])
    jingdu = cursor.fetchall()
    j1 = jingdu[0][0]
    cursor.execute('select weidu from table1 where id = %s',[i])
    weidu= cursor.fetchall()
    w1 = weidu[0][0]
    cursor.execute('select count(name) from table1 where jingdu- %s<=0.01 and weidu-%s <=0.01',[j1,w1])
    value = cursor.fetchall()
    v1 = value[0][0]
    print(v1)
    i = i + 1
cursor.close()
conn.close()
# Out:
# 37
# 51
# 35
# 55
# 29
# 54
# 26
# 29
# 2
# 11
# 14
# 17
# 25
# 8
# 7
# 11
# 8
# 2
# 25
# 7
# 5
# 16
# 16
# 29
# 27
# 6
# 6
# 21
# 37
# 64
# 39
# 17
# 25
# 64
# 41
# 17
# 104
# 94
# 104
# 69
# 81
# 88
# 155
# 80
# 59
# 56
# 132
# 77
# 88
# 122
# 64
# 82
# 169
# 109
# 90
# 184
# 13
# 112
# 59
# 66
# 79
# 75
# 94
# 187
# 145
# 113
# 63
# 79
# 100
# 15
# 142
# 20
# 98
# 26
# 68
# 39
# 159
# 15
# 87
# 60
# 97
# 74
# 67
# 64
# 5
# 30
# 21
# 64
# 8
# 70
# 67
# 101
# 7
# 10
# 4
# 104
# 7
# 3
# 21
# 55
# 113
# 35
# 104
# 5
# 6
# 63
# 35
# 14
# 7
# 51
# 3
# 6
# 70
# 2
# 3
# 105
# 113
# 4
# 15
# 6
# 159
# 6
# 12
# 9
# 37
# 362
# 277
# 237
# 306
# 218
# 268
# 252
# 360
# 248
# 246
# 324
# 219
# 297
# 242
# 283
# 242
# 245
# 243
# 251
# 216
# 236
# 244
# 234
# 234
# 335
# 242
# 229
# 193
# 267
# 242
# 231
# 305
# 110
# 152
# 63
# 350
# 224
# 244
# 94
# 199
# 314
# 147
# 354
# 401
# 288
# 100
# 199
# 221
# 240
# 178
# 165
# 2
# 8
# 124
# 164
# 180
# 266
# 246
# 185
# 185
# 189
# 220
# 230
# 46
# ...

# %%
import mysql.connector
conn = mysql.connector.connect(user='root', password='root', database='mathmodel')
cursor = conn.cursor()
i=1
#while(i <= 835):
    #cursor.execute('insert into user (id, name) values (%s, %s)', ['1', 'Michael'])
cursor.execute('select jingdu from table1 where id = %s',[i])
jingdu = cursor.fetchall()
#cursor.execute('select weidu from table1 where id = 1')
#weidu = cursor.fetchall()
    #cursor.execute('select count(name) from table1 where jingdu-22.56614225 <=0.01 and weidu-113.9808368 <=0.01')
    #values = cursor.fetchall()
print(jingdu)
    #i = i + 1
cursor.close()
conn.close()
# Out:
# [(Decimal('22.56614225'),)]

# %%
import mysql.connector
conn = mysql.connector.connect(user='root', password='root', database='mathmodel')
cursor = conn.cursor()
i=1
while(i <= 835):
    #cursor.execute('insert into user (id, name) values (%s, %s)', ['1', 'Michael'])
    cursor.execute('select jingdu from table1 where id = %s',[i])
    jingdu = cursor.fetchall()
    j1 = jingdu[0][0]
    cursor.execute('select weidu from table1 where id = %s',[i])
    weidu= cursor.fetchall()
    w1 = weidu[0][0]
    for j in range(1877):
        cursor.execute('select jingdu from table2 where id = %s',[j])
        jingdu2 = cursor.fetchall()
        j2 = jingdu2[0][0]
        cursor.execute('select weidu from table2 where id = %s',[j])
        weidu2= cursor.fetchall()
        w2 = weidu2[0][0]
        cursor.execute('select count(name) from table1 where %s - %s<=0.01 and %s - %s <=0.01',[j1,j2,w1,w2])
        value = cursor.fetchall()
        v2 = value[0][0]
        print(v2)
        j = j + 1
    i = i + 1
cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-30-c67c72ad11bb> in <module>()
#      12     w1 = weidu[0][0]
#      13     for j in range(1877):
# ---> 14         cursor.execute('select jingdu from table2 where id = %s',[j])
#      15         jingdu2 = cursor.fetchall()
#      16         j2 = jingdu2[0][0]
#
# D:\Anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     505             self._executed = stmt
#     506             try:
# --> 507                 self._handle_result(self._connection.cmd_query(stmt))
#     508             except errors.InterfaceError:
#     509                 if self._connection._have_next_result:  # pylint: disable=W0212
#
# D:\Anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query)
#     720         if not isinstance(query, bytes):
# ...

# %%
#问题2
import mysql.connector
conn = mysql.connector.connect(user='root', password='root', database='mathmodel')
cursor = conn.cursor()
i=1
while(i <= 835):
    #cursor.execute('insert into user (id, name) values (%s, %s)', ['1', 'Michael'])
    cursor.execute('select jingdu from table1 where id = %s',[i])
    jingdu = cursor.fetchall()
    j1 = jingdu[0][0]
    cursor.execute('select weidu from table1 where id = %s',[i])
    weidu= cursor.fetchall()
    w1 = weidu[0][0]
    cursor.execute('select count(id) from table2 where (jingdu- %s<=0.01 and jingdu- %s>=-0.01) and (weidu-%s <=0.01 and weidu-%s >= -0.01)',[j1,j1,w1,w1])
    value = cursor.fetchall()
    v2 = value[0][0]
    print(v2)
    i = i + 1
cursor.close()
conn.close()
# Out:
# 0
# 15
# 5
# 1
# 3
# 1
# 7
# 4
# 1
# 9
# 7
# 10
# 7
# 4
# 4
# 10
# 9
# 1
# 7
# 4
# 0
# 9
# 9
# 4
# 2
# 3
# 4
# 2
# 0
# 0
# 9
# 4
# 5
# 1
# 13
# 7
# 1
# 1
# 2
# 17
# 3
# 3
# 5
# 9
# 8
# 5
# 4
# 4
# 8
# 1
# 4
# 3
# 1
# 4
# 2
# 0
# 2
# 0
# 3
# 7
# 3
# 9
# 1
# 1
# 2
# 2
# 14
# 2
# 3
# 6
# 2
# 6
# 4
# 10
# 13
# 4
# 4
# 6
# 0
# 3
# 4
# 7
# 9
# 11
# 6
# 4
# 6
# 2
# 6
# 1
# 11
# 1
# 4
# 4
# 1
# 2
# 4
# 3
# 6
# 6
# 3
# 3
# 1
# 1
# 4
# 7
# 2
# 4
# 10
# 0
# 0
# 5
# 7
# 3
# 4
# 5
# 4
# 1
# 3
# 2
# 4
# 3
# 2
# 10
# 1
# 1
# 9
# 4
# 0
# 3
# 7
# 16
# 0
# 13
# 6
# 1
# 8
# 4
# 1
# 1
# 3
# 15
# 1
# 17
# 10
# 7
# 2
# 7
# 7
# 0
# 3
# 3
# 0
# 2
# 3
# 3
# 1
# 2
# 18
# 1
# 0
# 3
# 6
# 0
# 5
# 0
# 0
# 0
# 0
# 4
# 1
# 5
# 4
# 3
# 6
# 1
# 3
# 1
# 3
# 21
# 15
# 8
# 6
# 6
# 8
# 7
# 3
# 2
# 0
# 7
# 16
# 11
# 10
# 0
# 3
# 4
# 6
# 0
# 0
# 0
# 2
# 6
# 2
# 0
# 0
# 0
# 1
# 0
# 1
# 3
# 4
# 1
# 1
# 2
# 3
# 0
# 4
# 5
# 2
# 7
# 1
# 0
# 2
# 6
# 0
# 1
# 0
# 6
# 2
# 5
# 2
# 0
# 1
# 4
# 2
# 5
# 5
# 1
# 12
# 6
# 9
# 0
# 13
# ...

# %%
#问题1
import mysql.connector
conn = mysql.connector.connect(user='root', password='root', database='mathmodel')
cursor = conn.cursor()
i=1
while(i <= 835):
    #cursor.execute('insert into user (id, name) values (%s, %s)', ['1', 'Michael'])
    cursor.execute('select jingdu from table1 where id = %s',[i])
    jingdu = cursor.fetchall()
    j1 = jingdu[0][0]
    cursor.execute('select weidu from table1 where id = %s',[i])
    weidu= cursor.fetchall()
    w1 = weidu[0][0]
    cursor.execute('select count(name) from table1 where (jingdu- %s<=0.05 and jingdu- %s>=-0.05) and (weidu-%s <=0.05 and weidu-%s >= -0.05)',[j1,j1,w1,w1])
    value = cursor.fetchall()
    v1 = value[0][0]
    print(v1)
    i = i + 1
cursor.close()
conn.close()
# Out:
# 23
# 8
# 19
# 2
# 33
# 2
# 29
# 32
# 21
# 37
# 33
# 34
# 27
# 25
# 24
# 38
# 30
# 21
# 27
# 21
# 20
# 32
# 34
# 17
# 19
# 19
# 29
# 38
# 25
# 17
# 12
# 36
# 33
# 18
# 12
# 34
# 15
# 2
# 14
# 12
# 18
# 6
# 9
# 11
# 18
# 6
# 11
# 15
# 9
# 2
# 18
# 19
# 1
# 11
# 6
# 6
# 18
# 7
# 10
# 18
# 19
# 13
# 2
# 6
# 8
# 11
# 17
# 16
# 9
# 13
# 6
# 9
# 9
# 11
# 14
# 6
# 10
# 13
# 5
# 19
# 15
# 14
# 9
# 14
# 16
# 12
# 14
# 3
# 16
# 9
# 18
# 11
# 12
# 17
# 15
# 11
# 12
# 11
# 14
# 15
# 11
# 6
# 13
# 24
# 12
# 17
# 9
# 16
# 30
# 6
# 11
# 28
# 19
# 11
# 13
# 15
# 11
# 15
# 21
# 27
# 10
# 17
# 20
# 36
# 14
# 2
# 29
# 38
# 18
# 44
# 18
# 27
# 2
# 21
# 41
# 7
# 38
# 17
# 6
# 6
# 10
# 22
# 40
# 27
# 46
# 18
# 40
# 16
# 16
# 4
# 10
# 10
# 9
# 5
# 10
# 10
# 10
# 27
# 36
# 26
# 4
# 11
# 44
# 18
# 46
# 15
# 17
# 2
# 2
# 31
# 22
# 46
# 39
# 39
# 48
# 27
# 14
# 7
# 27
# 39
# 48
# 19
# 41
# 51
# 46
# 48
# 45
# 44
# 6
# 45
# 25
# 43
# 20
# 19
# 38
# 31
# 40
# 6
# 11
# 11
# 18
# 20
# 18
# 10
# 10
# 10
# 7
# 1
# 7
# ...

# %%
#问题3
import mysql.connector
conn = mysql.connector.connect(user='root', password='root', database='mathmodel')
cursor = conn.cursor()
i=1
while(i <= 835):
    #cursor.execute('insert into user (id, name) values (%s, %s)', ['1', 'Michael'])
    cursor.execute('select jingdu from table1 where id = %s',[i])
    jingdu = cursor.fetchall()
    j1 = jingdu[0][0]
    cursor.execute('select weidu from table1 where id = %s',[i])
    weidu= cursor.fetchall()
    w1 = weidu[0][0]
    cursor.execute('select SUM(score) from table2 where (jingdu- %s<=0.01 and jingdu- %s>=-0.01) and (weidu-%s <=0.01 and weidu-%s >= -0.01)',[j1,j1,w1,w1])
    value = cursor.fetchall()
    v2 = value[0][0]
    print(v2)
    i = i + 1
cursor.close()
conn.close()
# Out:
# None
# 391.52250000000000000000
# 38072.10340000000000000000
# 0.36360000000000000000
# 10977.88210000000000000000
# 0.36360000000000000000
# 140.41640000000000000000
# 337.99300000000000000000
# 19.92310000000000000000
# 822.11740000000000000000
# 410.37980000000000000000
# 577.51050000000000000000
# 161.74520000000000000000
# 60.10910000000000000000
# 174.01050000000000000000
# 822.15840000000000000000
# 448.56390000000000000000
# 19.92310000000000000000
# 161.74520000000000000000
# 174.01050000000000000000
# None
# 418.88970000000000000000
# 440.46530000000000000000
# 63.75390000000000000000
# 976.37210000000000000000
# 22.28610000000000000000
# 58.14820000000000000000
# 20.30100000000000000000
# None
# None
# 1389.11120000000000000000
# 208.67050000000000000000
# 11313.71080000000000000000
# 19.92310000000000000000
# 1943.82990000000000000000
# 537.32450000000000000000
# 19.92310000000000000000
# 0.36930000000000000000
# 21.91540000000000000000
# 1043.54430000000000000000
# ...
